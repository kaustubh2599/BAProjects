# %%
# !pip install --upgrade pandas
# Out:
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.4
#     Uninstalling pandas-1.1.4:
#       Successfully uninstalled pandas-1.1.4
# ERROR: phik 0.12.0 has requirement scipy>=1.5.2, but you'll have scipy 1.5.0 which is incompatible.
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'C:\\Users\\LENOVO\\anaconda3\\Lib\\site-packages\\~-ndas\\_libs\\algos.cp38-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
# !pip install py-openaq

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib 
import openaq

# %%
api = openaq.OpenAQ()

# %%
London = api.measurements(city='London', limit=5000, df=True)
Paris = api.measurements(city='Paris', limit=5000, df=True)
Madrid = api.measurements(city='Madrid', limit=5000, df=True)
Berlin = api.measurements(city='Berlin', limit=5000, df=True)
Rome = api.measurements(city='Roma', limit=5000, df=True)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\openaq\decorators.py:57: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   data = pd.io.json.json_normalize(resp)

# %% [markdown]
# ### Compiling All Cities in a DataFrame named Cities

# %%
Cities=pd.concat([London,Paris,Madrid, Berlin, Rome],axis=0)

# %%
Cities
# Out:
#                               location parameter  value  \
# date.local
# 2021-10-07 19:00:00      London Eltham       no2   17.0
# 2021-10-07 19:00:00    Southend-on-Sea      pm25    7.0
# 2021-10-07 19:00:00      London Eltham      pm25    5.0
# 2021-10-07 19:00:00  London Harlington       no2   31.0
# 2021-10-07 19:00:00    Southend-on-Sea      pm10   12.0
# ...                                ...       ...    ...
# 2021-09-30 12:00:00            IT0952A       no2    3.0
# 2021-09-30 12:00:00            IT1841A       no2   11.0
# 2021-09-30 12:00:00            IT0888A       no2   44.0
# 2021-09-30 12:00:00            IT0885A        o3   44.0
# 2021-09-30 12:00:00            IT0956A        o3   40.0
#
#                                        unit country    city  \
# date.local
# 2021-10-07 19:00:00  b'\xc2\xb5g/m\xc2\xb3'      GB  London
# 2021-10-07 19:00:00  b'\xc2\xb5g/m\xc2\xb3'      GB  London
# 2021-10-07 19:00:00  b'\xc2\xb5g/m\xc2\xb3'      GB  London
# ...

# %% [markdown]
# ### Most Polluted Cities in terms of SO2, CO and pm25

# %%
AirQualityCO = Cities[Cities['parameter']== 'co']

# %%
AirQualityCO
# Out:
#                     location parameter  value                    unit country  \
# date.local
# 2021-10-07 18:00:00  ES1568A        co  400.0  b'\xc2\xb5g/m\xc2\xb3'      ES
# 2021-10-07 18:00:00  ES1613A        co  500.0  b'\xc2\xb5g/m\xc2\xb3'      ES
# 2021-10-07 15:00:00  ES1806A        co  400.0  b'\xc2\xb5g/m\xc2\xb3'      ES
# 2021-10-07 18:00:00  ES1810A        co  200.0  b'\xc2\xb5g/m\xc2\xb3'      ES
# 2021-10-07 18:00:00  ES1802A        co  200.0  b'\xc2\xb5g/m\xc2\xb3'      ES
# ...                      ...       ...    ...                     ...     ...
# 2021-09-30 12:00:00  IT0885A        co  600.0  b'\xc2\xb5g/m\xc2\xb3'      IT
# 2021-09-30 12:00:00  IT2171A        co  600.0  b'\xc2\xb5g/m\xc2\xb3'      IT
# 2021-09-30 12:00:00  IT0888A        co  300.0  b'\xc2\xb5g/m\xc2\xb3'      IT
# 2021-09-30 12:00:00  IT1837A        co  600.0  b'\xc2\xb5g/m\xc2\xb3'      IT
# 2021-09-30 12:00:00  IT0953A        co  300.0  b'\xc2\xb5g/m\xc2\xb3'      IT
#
# ...

# %%
AirQualityCO.head(6)
# Out:
#                     location parameter  value                    unit country  \
# date.local
# 2021-10-07 18:00:00  ES1568A        co  400.0  b'\xc2\xb5g/m\xc2\xb3'      ES
# 2021-10-07 18:00:00  ES1613A        co  500.0  b'\xc2\xb5g/m\xc2\xb3'      ES
# 2021-10-07 15:00:00  ES1806A        co  400.0  b'\xc2\xb5g/m\xc2\xb3'      ES
# 2021-10-07 18:00:00  ES1810A        co  200.0  b'\xc2\xb5g/m\xc2\xb3'      ES
# 2021-10-07 18:00:00  ES1802A        co  200.0  b'\xc2\xb5g/m\xc2\xb3'      ES
# 2021-10-07 18:00:00  ES1563A        co  400.0  b'\xc2\xb5g/m\xc2\xb3'      ES
#
#                        city                  date.utc  coordinates.latitude  \
# date.local
# 2021-10-07 18:00:00  Madrid 2021-10-07 16:00:00+00:00              40.32417
# 2021-10-07 18:00:00  Madrid 2021-10-07 16:00:00+00:00              40.66639
# 2021-10-07 15:00:00  Madrid 2021-10-07 16:00:00+00:00              40.28694
# 2021-10-07 18:00:00  Madrid 2021-10-07 16:00:00+00:00              40.25194
# ...

# %%
fig, ax = plt.subplots(1, figsize=(14,10))


ax = sns.boxplot(
    x='city',
    y='value',
    data=AirQualityCO,
    fliersize=0,
    palette='deep',
    ax=ax)


ax.set_ylim([0,1000])
ax.set_ylabel("CO", fontsize=20)
ax.set_xlabel("city")


sns.despine(offset=10)

plt.show()

# %% [markdown]
# ### Roma City is most polluted interms of CO

# %%
AirQualitySO2= Cities[Cities['parameter']=='so2']

# %%
AirQualitySO2
# Out:
#                     location parameter  value                    unit country  \
# date.local
# 2021-10-07 18:00:00  ES1568A       so2    1.0  b'\xc2\xb5g/m\xc2\xb3'      ES
# 2021-10-07 15:00:00  ES1806A       so2    3.0  b'\xc2\xb5g/m\xc2\xb3'      ES
# 2021-10-07 18:00:00  ES1802A       so2    1.0  b'\xc2\xb5g/m\xc2\xb3'      ES
# 2021-10-07 15:00:00  ES1803A       so2    1.0  b'\xc2\xb5g/m\xc2\xb3'      ES
# 2021-10-07 18:00:00  ES1810A       so2    1.0  b'\xc2\xb5g/m\xc2\xb3'      ES
# ...                      ...       ...    ...                     ...     ...
# 2021-09-30 12:00:00  IT1835A       so2    1.8  b'\xc2\xb5g/m\xc2\xb3'      IT
# 2021-09-30 12:00:00  IT0953A       so2    2.3  b'\xc2\xb5g/m\xc2\xb3'      IT
# 2021-09-30 12:00:00  IT0885A       so2    1.3  b'\xc2\xb5g/m\xc2\xb3'      IT
# 2021-09-30 12:00:00  IT0884A       so2    6.2  b'\xc2\xb5g/m\xc2\xb3'      IT
# 2021-09-30 12:00:00  IT2012A       so2    2.5  b'\xc2\xb5g/m\xc2\xb3'      IT
#
# ...

# %%
AirQualitySO2.head(6)
# Out:
#                     location parameter  value                    unit country  \
# date.local
# 2021-10-07 18:00:00  ES1568A       so2    1.0  b'\xc2\xb5g/m\xc2\xb3'      ES
# 2021-10-07 15:00:00  ES1806A       so2    3.0  b'\xc2\xb5g/m\xc2\xb3'      ES
# 2021-10-07 18:00:00  ES1802A       so2    1.0  b'\xc2\xb5g/m\xc2\xb3'      ES
# 2021-10-07 15:00:00  ES1803A       so2    1.0  b'\xc2\xb5g/m\xc2\xb3'      ES
# 2021-10-07 18:00:00  ES1810A       so2    1.0  b'\xc2\xb5g/m\xc2\xb3'      ES
# 2021-10-07 18:00:00  ES1563A       so2    3.0  b'\xc2\xb5g/m\xc2\xb3'      ES
#
#                        city                  date.utc  coordinates.latitude  \
# date.local
# 2021-10-07 18:00:00  Madrid 2021-10-07 16:00:00+00:00              40.32417
# 2021-10-07 15:00:00  Madrid 2021-10-07 16:00:00+00:00              40.28694
# 2021-10-07 18:00:00  Madrid 2021-10-07 16:00:00+00:00              40.91028
# 2021-10-07 15:00:00  Madrid 2021-10-07 16:00:00+00:00              40.63389
# ...

# %%
fig, ax = plt.subplots(1, figsize=(14,10))


ax = sns.boxplot(
    x='city',
    y='value',
    data=AirQualitySO2,
    fliersize=0,
    palette='deep',
    ax=ax)


ax.set_ylim([0,50])
ax.set_ylabel("SO2", fontsize=20)
ax.set_xlabel("city")


sns.despine(offset=10)

plt.show()

# %% [markdown]
# ### Roma is most Poluted City in terms of SO2

# %%
AirQualityPM25 = Cities[Cities['parameter']== 'pm25']

# %%
AirQualityPM25
# Out:
#                               location parameter  value  \
# date.local
# 2021-10-07 19:00:00    Southend-on-Sea      pm25   7.00
# 2021-10-07 19:00:00      London Eltham      pm25   5.00
# 2021-10-07 19:00:00  London Harlington      pm25   6.00
# 2021-10-07 18:00:00      London Eltham      pm25   4.00
# 2021-10-07 18:00:00  London Harlington      pm25   6.00
# ...                                ...       ...    ...
# 2021-08-29 02:00:00            DEBE034      pm25   8.25
# 2021-08-29 02:00:00            DEBE069      pm25   9.48
# 2021-08-29 02:00:00            DEBE010      pm25   8.48
# 2021-08-29 02:00:00            DEBE061      pm25   9.33
# 2021-08-29 02:00:00            DEBE032      pm25   9.96
#
#                                        unit country    city  \
# date.local
# 2021-10-07 19:00:00  b'\xc2\xb5g/m\xc2\xb3'      GB  London
# 2021-10-07 19:00:00  b'\xc2\xb5g/m\xc2\xb3'      GB  London
# 2021-10-07 19:00:00  b'\xc2\xb5g/m\xc2\xb3'      GB  London
# ...

# %%
AirQualityPM25.head(6)
# Out:
#                               location parameter  value  \
# date.local
# 2021-10-07 19:00:00    Southend-on-Sea      pm25    7.0
# 2021-10-07 19:00:00      London Eltham      pm25    5.0
# 2021-10-07 19:00:00  London Harlington      pm25    6.0
# 2021-10-07 18:00:00      London Eltham      pm25    4.0
# 2021-10-07 18:00:00  London Harlington      pm25    6.0
# 2021-10-07 18:00:00    Southend-on-Sea      pm25    7.0
#
#                                        unit country    city  \
# date.local
# 2021-10-07 19:00:00  b'\xc2\xb5g/m\xc2\xb3'      GB  London
# 2021-10-07 19:00:00  b'\xc2\xb5g/m\xc2\xb3'      GB  London
# 2021-10-07 19:00:00  b'\xc2\xb5g/m\xc2\xb3'      GB  London
# 2021-10-07 18:00:00  b'\xc2\xb5g/m\xc2\xb3'      GB  London
# 2021-10-07 18:00:00  b'\xc2\xb5g/m\xc2\xb3'      GB  London
# 2021-10-07 18:00:00  b'\xc2\xb5g/m\xc2\xb3'      GB  London
#
#                                      date.utc  coordinates.latitude  \
# date.local
# ...

# %%
fig, ax = plt.subplots(1, figsize=(14,10))


ax = sns.boxplot(
    x='city',
    y='value',
    data=AirQualityPM25,
    fliersize=0,
    palette='deep',
    ax=ax)


ax.set_ylim([0,50])
ax.set_ylabel("PM25", fontsize=20)
ax.set_xlabel("city")


sns.despine(offset=10)

plt.show()

# %% [markdown]
# ### Paris is most Polluted City in Terms of PM25

# %% [markdown]
# # Part 2

# %% [markdown]
# ### Definiing a function which, given a number, computes the square root

# %%
def Sqrt_Value (x):
    x= np.sqrt(x)
    return x
x=9

# %%
Sqrt_Value(x)
# Out:
# 3.0

# %% [markdown]
# ### Using the function to compute the square root of the column value in the Cities DataFrame

# %%
Cities['Sqrt_Value'] = Cities['value'].apply(Sqrt_Value)

# %%
Cities
# Out:
#                               location parameter  value  \
# date.local
# 2021-10-07 19:00:00      London Eltham       no2   17.0
# 2021-10-07 19:00:00    Southend-on-Sea      pm25    7.0
# 2021-10-07 19:00:00      London Eltham      pm25    5.0
# 2021-10-07 19:00:00  London Harlington       no2   31.0
# 2021-10-07 19:00:00    Southend-on-Sea      pm10   12.0
# ...                                ...       ...    ...
# 2021-09-30 12:00:00            IT0952A       no2    3.0
# 2021-09-30 12:00:00            IT1841A       no2   11.0
# 2021-09-30 12:00:00            IT0888A       no2   44.0
# 2021-09-30 12:00:00            IT0885A        o3   44.0
# 2021-09-30 12:00:00            IT0956A        o3   40.0
#
#                                        unit country    city  \
# date.local
# 2021-10-07 19:00:00  b'\xc2\xb5g/m\xc2\xb3'      GB  London
# 2021-10-07 19:00:00  b'\xc2\xb5g/m\xc2\xb3'      GB  London
# 2021-10-07 19:00:00  b'\xc2\xb5g/m\xc2\xb3'      GB  London
# ...

# %% [markdown]
# ### Computing the Square Root of the Column Values using a Lambda Function

# %%
Cities['Updated_Values']= Cities['value'].apply(lambda x : Sqrt_Value(x))

# %%
Cities
# Out:
#                               location parameter  value  \
# date.local
# 2021-10-07 19:00:00      London Eltham       no2   17.0
# 2021-10-07 19:00:00    Southend-on-Sea      pm25    7.0
# 2021-10-07 19:00:00      London Eltham      pm25    5.0
# 2021-10-07 19:00:00  London Harlington       no2   31.0
# 2021-10-07 19:00:00    Southend-on-Sea      pm10   12.0
# ...                                ...       ...    ...
# 2021-09-30 12:00:00            IT0952A       no2    3.0
# 2021-09-30 12:00:00            IT1841A       no2   11.0
# 2021-09-30 12:00:00            IT0888A       no2   44.0
# 2021-09-30 12:00:00            IT0885A        o3   44.0
# 2021-09-30 12:00:00            IT0956A        o3   40.0
#
#                                        unit country    city  \
# date.local
# 2021-10-07 19:00:00  b'\xc2\xb5g/m\xc2\xb3'      GB  London
# 2021-10-07 19:00:00  b'\xc2\xb5g/m\xc2\xb3'      GB  London
# 2021-10-07 19:00:00  b'\xc2\xb5g/m\xc2\xb3'      GB  London
# ...

# %% [markdown]
# ### Changing the Name of City "London" to "Greater London" in the Cities DataFrame

# %%
del(London['city'])

# %%
London['city']='Greater London'

# %%
London
# Out:
#                                               location parameter  value  \
# date.local
# 2021-10-07 19:00:00                      London Eltham       no2   17.0
# 2021-10-07 19:00:00                    Southend-on-Sea      pm25    7.0
# 2021-10-07 19:00:00                      London Eltham      pm25    5.0
# 2021-10-07 19:00:00                  London Harlington       no2   31.0
# 2021-10-07 19:00:00                    Southend-on-Sea      pm10   12.0
# ...                                                ...       ...    ...
# 2021-09-20 15:00:00                    Southend-on-Sea       no2    7.0
# 2021-09-20 15:00:00                      London Eltham      pm10   10.0
# 2021-09-20 15:00:00  London Haringey Priory Park South        o3   38.0
# 2021-09-20 14:00:00  London Haringey Priory Park South        o3   36.0
# 2021-09-20 14:00:00                    Southend-on-Sea        o3   26.0
#
#                                        unit country                  date.utc  \
# ...
